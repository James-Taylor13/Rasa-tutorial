# %%
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %%
# !pip install rasa
# Out:
# Collecting rasa
#   Using cached rasa-2.8.9-py3-none-any.whl (767 kB)
# Collecting colorhash<1.1.0,>=1.0.2
#   Using cached colorhash-1.0.3-py3-none-any.whl (4.0 kB)
# ERROR: Cannot uninstall 'ruamel-yaml'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: scipy<2.0.0,>=1.4.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.5.2)
# Requirement already satisfied: regex<2021.8,>=2020.6 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2020.10.15)
# Collecting jsonpickle<2.1,>=1.3
#   Using cached jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: sanic<20.12.0,>=19.12.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (20.9.1)
# Requirement already satisfied: numpy<1.20.0,>=1.19.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.19.5)
# Requirement already satisfied: rocketchat_API<1.17.0,>=0.6.31 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (50.3.1.post20201107)
# Requirement already satisfied: pytz<2022.0,>=2019.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2020.1)
# Requirement already satisfied: terminaltables<3.2.0,>=3.1.0 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.1.0)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.8.1)
# Collecting ruamel.yaml<0.17.0,>=0.16.5
#   Using cached ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting pykwalify<1.9,>=1.7
#   Using cached pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: coloredlogs<16,>=10 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (15.0.1)
# Requirement already satisfied: jsonschema<3.3,>=3.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.2.0)
# Collecting aio-pika<7.0.0,>=6.7.1
#   Using cached aio_pika-6.8.0-py3-none-any.whl (42 kB)
# Requirement already satisfied: tensorflow_hub<0.13,>=0.10 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.12.0)
# Requirement already satisfied: apscheduler<3.8,>=3.6 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.7.0)
# Requirement already satisfied: aiohttp!=3.7.4.post0,<3.8,>=3.6 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.7.4)
# Requirement already satisfied: mattermostwrapper<2.3,>=2.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.2)
# Requirement already satisfied: tensorflow-addons<0.15,>=0.14 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.14.0)
# Collecting tensorflow-estimator<2.7,>=2.6
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Collecting boto3<2.0,>=1.12
#   Using cached boto3-1.18.58-py3-none-any.whl (131 kB)
# Collecting fbmessenger<6.1.0,>=6.0.0
#   Using cached fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: twilio<6.51,>=6.26 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (6.50.1)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\62\f7\00\cc965b59765a286cdb511dffa456b289c95ee01fbcb43b861a\sanic_jwt-1.6.0-py3-none-any.whl
# Requirement already satisfied: scikit-learn<0.25,>=0.22 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.23.2)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\bf\4f\4e\831c191578fd8b676533e1bf85e4710e3215c72c1d3d0d6710\colorclass-2.2.0-py3-none-any.whl
# Requirement already satisfied: rasa-sdk<3.0.0,>=2.8.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.8.2)
# Requirement already satisfied: cloudpickle<1.7,>=1.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.6.0)
# Requirement already satisfied: sanic-cors<0.11.0,>=0.10.0b1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.10.0.post3)
# Requirement already satisfied: joblib<1.1.0,>=0.15.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.17.0)
# Requirement already satisfied: pyTelegramBotAPI<4.0.0,>=3.7.3 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.8.3)
# Requirement already satisfied: packaging<21.0,>=20.0 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (20.4)
# Collecting absl-py<0.14,>=0.9
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# Requirement already satisfied: psycopg2-binary<2.10.0,>=2.8.2 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.9.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.4; sys_platform == "win32" in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.4.4)
# Requirement already satisfied: pydot<1.5,>=1.4 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.4.2)
# Collecting questionary<1.10.0,>=1.5.1
#   Using cached questionary-1.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: matplotlib<3.4,>=3.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.3.2)
# Requirement already satisfied: tqdm<5.0,>=4.31 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (4.50.2)
# Requirement already satisfied: networkx<2.6,>=2.4 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.5)
# Requirement already satisfied: async_generator<1.11,>=1.10 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.10)
# Collecting sentry-sdk<1.3.0,>=0.17.0
#   Using cached sentry_sdk-1.2.0-py2.py3-none-any.whl (133 kB)
# Collecting python-socketio<6,>=4.4
#   Using cached python_socketio-5.4.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: PyJWT[crypto]<3.0.0,>=2.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.2.0)
# Requirement already satisfied: attrs<21.3,>=19.3 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (20.3.0)
# Requirement already satisfied: python-engineio!=5.0.0,<6,>=4 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (4.2.1)
# Collecting tensorflow<2.7,>=2.6
#   Using cached tensorflow-2.6.0-cp38-cp38-win_amd64.whl (423.2 MB)
# Requirement already satisfied: SQLAlchemy<1.5.0,>=1.3.3 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.3.20)
# Collecting prompt-toolkit<3.0,>=2.0
#   Using cached prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
# Collecting kafka-python<3.0,>=1.4
#   Using cached kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
# Requirement already satisfied: redis<4.0,>=3.4 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.5.3)
# Requirement already satisfied: slackclient<3.0.0,>=2.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.9.3)
# Requirement already satisfied: tensorflow-probability<0.14,>=0.11 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (0.13.0)
# Collecting sklearn-crfsuite<0.4,>=0.3
#   Using cached sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: ujson<5.0,>=1.35 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (4.0.1)
# Requirement already satisfied: webexteamssdk<1.7.0,>=1.1.1 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (1.6)
# Collecting oauth2client==4.1.3
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: pymongo[srv,tls]<3.11,>=3.8 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (3.10.1)
# Requirement already satisfied: requests<3.0,>=2.23 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa) (2.24.0)
# Requirement already satisfied: httptools>=0.0.10 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic<20.12.0,>=19.12.2->rasa) (0.3.0)
# Requirement already satisfied: aiofiles>=0.3.0 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic<20.12.0,>=19.12.2->rasa) (0.7.0)
# Requirement already satisfied: multidict==5.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic<20.12.0,>=19.12.2->rasa) (5.0.0)
# Requirement already satisfied: websockets<9.0,>=8.1 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic<20.12.0,>=19.12.2->rasa) (8.1)
# Requirement already satisfied: httpx==0.15.4 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic<20.12.0,>=19.12.2->rasa) (0.15.4)
# Requirement already satisfied: six>=1.5 in c:\users\james taylor\anaconda3\lib\site-packages (from python-dateutil<2.9,>=2.8->rasa) (1.15.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in c:\users\james taylor\anaconda3\lib\site-packages (from ruamel.yaml<0.17.0,>=0.16.5->rasa) (0.2.6)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c\docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\james taylor\anaconda3\lib\site-packages (from coloredlogs<16,>=10->rasa) (10.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\james taylor\anaconda3\lib\site-packages (from jsonschema<3.3,>=3.2->rasa) (0.17.3)
# Collecting aiormq<4,>=3.2.3
#   Using cached aiormq-3.3.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: yarl in c:\users\james taylor\anaconda3\lib\site-packages (from aio-pika<7.0.0,>=6.7.1->rasa) (1.7.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\james taylor\anaconda3\lib\site-packages (from tensorflow_hub<0.13,>=0.10->rasa) (3.18.0)
# Requirement already satisfied: tzlocal~=2.0 in c:\users\james taylor\anaconda3\lib\site-packages (from apscheduler<3.8,>=3.6->rasa) (2.1)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\james taylor\anaconda3\lib\site-packages (from aiohttp!=3.7.4.post0,<3.8,>=3.6->rasa) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\james taylor\anaconda3\lib\site-packages (from aiohttp!=3.7.4.post0,<3.8,>=3.6->rasa) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\james taylor\anaconda3\lib\site-packages (from aiohttp!=3.7.4.post0,<3.8,>=3.6->rasa) (3.7.4.3)
# Requirement already satisfied: typeguard>=2.7 in c:\users\james taylor\anaconda3\lib\site-packages (from tensorflow-addons<0.15,>=0.14->rasa) (2.12.1)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Using cached s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.22.0,>=1.21.58
#   Using cached botocore-1.21.58-py3-none-any.whl (8.0 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from scikit-learn<0.25,>=0.22->rasa) (2.1.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.5 in c:\users\james taylor\anaconda3\lib\site-packages (from rasa-sdk<3.0.0,>=2.8.1->rasa) (1.26.7)
# Requirement already satisfied: sanic-plugins-framework>=0.9.0 in c:\users\james taylor\anaconda3\lib\site-packages (from sanic-cors<0.11.0,>=0.10.0b1->rasa) (0.9.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\james taylor\anaconda3\lib\site-packages (from packaging<21.0,>=20.0->rasa) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\james taylor\anaconda3\lib\site-packages (from matplotlib<3.4,>=3.1->rasa) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\james taylor\anaconda3\lib\site-packages (from matplotlib<3.4,>=3.1->rasa) (8.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\james taylor\anaconda3\lib\site-packages (from matplotlib<3.4,>=3.1->rasa) (1.3.0)
# Requirement already satisfied: certifi>=2020.06.20 in c:\users\james taylor\anaconda3\lib\site-packages (from matplotlib<3.4,>=3.1->rasa) (2020.6.20)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\james taylor\anaconda3\lib\site-packages (from networkx<2.6,>=2.4->rasa) (4.4.2)
# Collecting bidict>=0.21.0
#   Using cached bidict-0.21.3-py3-none-any.whl (36 kB)
# Requirement already satisfied: cryptography>=3.3.1; extra == "crypto" in c:\users\james taylor\anaconda3\lib\site-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (35.0.0)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501\termcolor-1.1.0-py3-none-any.whl
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting keras~=2.6
#   Using cached keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.37.0
#   Using cached grpcio-1.41.0-cp38-cp38-win_amd64.whl (3.2 MB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73\wrapt-1.12.1-py3-none-any.whl
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: wheel~=0.35 in c:\users\james taylor\anaconda3\lib\site-packages (from tensorflow<2.7,>=2.6->rasa) (0.35.1)
# Processing c:\users\james taylor\appdata\local\pip\cache\wheels\f1\60\77\22b9b5887bd47801796a856f47650d9789c74dc3161a26d608\clang-5.0-py3-none-any.whl
# Requirement already satisfied: wcwidth in c:\users\james taylor\anaconda3\lib\site-packages (from prompt-toolkit<3.0,>=2.0->rasa) (0.2.5)
# Requirement already satisfied: dm-tree in c:\users\james taylor\anaconda3\lib\site-packages (from tensorflow-probability<0.14,>=0.11->rasa) (0.1.6)
# Collecting python-crfsuite>=0.8.3
#   Using cached python_crfsuite-0.9.7-cp38-cp38-win_amd64.whl (156 kB)
# Requirement already satisfied: tabulate in c:\users\james taylor\appdata\roaming\python\python38\site-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.8.9)
# Requirement already satisfied: requests-toolbelt in c:\users\james taylor\anaconda3\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.9.1)
# Requirement already satisfied: future in c:\users\james taylor\anaconda3\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.18.2)
# Collecting rsa>=3.1.4
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting httplib2>=0.9.1
#   Using cached httplib2-0.20.1-py3-none-any.whl (96 kB)
# Collecting pyasn1>=0.1.7
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules>=0.0.5
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in c:\users\james taylor\anaconda3\lib\site-packages (from pymongo[srv,tls]<3.11,>=3.8->rasa) (1.16.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\james taylor\anaconda3\lib\site-packages (from requests<3.0,>=2.23->rasa) (2.10)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\james taylor\anaconda3\lib\site-packages (from httpx==0.15.4->sanic<20.12.0,>=19.12.2->rasa) (1.5.0)
# Requirement already satisfied: httpcore==0.11.* in c:\users\james taylor\anaconda3\lib\site-packages (from httpx==0.15.4->sanic<20.12.0,>=19.12.2->rasa) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\james taylor\anaconda3\lib\site-packages (from httpx==0.15.4->sanic<20.12.0,>=19.12.2->rasa) (1.2.0)
# Requirement already satisfied: pyreadline3; sys_platform == "win32" and python_version >= "3.8" in c:\users\james taylor\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs<16,>=10->rasa) (3.3)
# Collecting pamqp==2.3.0
#   Using cached pamqp-2.3.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\james taylor\anaconda3\lib\site-packages (from cryptography>=3.3.1; extra == "crypto"->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (1.14.3)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\james taylor\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6->rasa) (1.0.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\james taylor\anaconda3\lib\site-packages (from httpcore==0.11.*->httpx==0.15.4->sanic<20.12.0,>=19.12.2->rasa) (0.9.0)
# Requirement already satisfied: pycparser in c:\users\james taylor\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.1; extra == "crypto"->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (2.20)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\james taylor\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6->rasa) (4.2.2)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: colorhash, jsonpickle, ruamel.yaml, docopt, pykwalify, pamqp, aiormq, aio-pika, tensorflow-estimator, jmespath, botocore, s3transfer, boto3, fbmessenger, sanic-jwt, colorclass, absl-py, prompt-toolkit, questionary, sentry-sdk, bidict, python-socketio, termcolor, astunparse, h5py, markdown, tensorboard-data-server, grpcio, pyasn1, rsa, pyasn1-modules, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-plugin-wit, tensorboard, keras, keras-preprocessing, google-pasta, flatbuffers, wrapt, gast, opt-einsum, clang, tensorflow, kafka-python, python-crfsuite, sklearn-crfsuite, httplib2, oauth2client, rasa
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel-yaml 0.15.87

# %%
from rasa.cli.scaffold import create_initial_project
import os

project = "test-project"
create_initial_project(project)

# move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e069a97987ca> in <module>
# ----> 1 from rasa.cli.scaffold import create_initial_project
#       2 import os
#       3
#       4 project = "test-project"
#       5 create_initial_project(project)
#
# ModuleNotFoundError: No module named 'rasa'
